# %%
import pandas as pd
import numpy as np
print("Pandas version: ", pd.__version__)
# Out:
# Pandas version:  1.5.3

# %% [markdown]
# При чтении csv файлов рекомендуется указывать кодировку файла, чтобы избежать ошибок и нечитаемых символов.
# Также существует функция чтения Excel-файлов: pd.read_excel()

# %%
anime = pd.read_csv("archive/anime.csv")
rating = pd.read_csv("archive/rating.csv")
anime_modified = anime.set_index("name")

# %% [markdown]
# Можно вручную создавать датафреймы, как показано ниже.

# %%
df = pd.DataFrame([[1, "Bob", "Builder"],
            [2, "Sally", "Baker"],
            [3, "Scott", "Candle Stick Maker"]], 
                  columns = ["id", "name", "occupation"])
df.append(df.sum(axis=0), ignore_index=True)
df
# Out:
# /tmp/ipykernel_5553/1548636941.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(df.sum(axis=0), ignore_index=True)
#    id   name          occupation
# 0   1    Bob             Builder
# 1   2  Sally               Baker
# 2   3  Scott  Candle Stick Maker

# %% [markdown]
# Функция для копирования датафреймов copy() (пригодится, если нужно внести изменения в данные, но сохранить оригинал)

# %%
anime_copy = anime.copy(deep = True)

# %% [markdown]
# Экспорт данных в формате csv to_csv() (аналогично есть to_excel())

# %%
rating[:10].to_csv("10rows_rating", index = False)

# %% [markdown]
# Вывод первых и последних n записей: head(), tail()

# %%
print(anime.head(3))
print(rating.tail(5))
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
#
#    members
# 0   200630
# 1   793665
# 2   114262
#          user_id  anime_id  rating
# 7813732    73515     16512       7
# 7813733    73515     17187       9
# 7813734    73515     22145      10
# 7813735    73516       790       9
# 7813736    73516      8074       9

# %%
print(len(anime))
# Out:
# 12294

# %%
print(len(rating))
# Out:
# 7813737

# %%
print(len(rating["user_id"].unique()))
# Out:
# 73515

# %%
anime.info
# Out:
# <bound method DataFrame.info of        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 1          5114                   Fullmetal Alchemist: Brotherhood
# 2         28977                                           Gintama°
# 3          9253                                        Steins;Gate
# 4          9969                                      Gintama&#039;
# ...         ...                                                ...
# 12289      9316       Toushindai My Lover: Minami tai Mecha-Minami
# 12290      5543                                        Under World
# 12291      5621                     Violence Gekiga David no Hoshi
# 12292      6133  Violence Gekiga Shin David no Hoshi: Inma Dens...
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# ...

# %%
anime.dtypes
# Out:
# anime_id      int64
# name         object
# genre        object
# type         object
# episodes     object
# rating      float64
# members       int64
# dtype: object

# %%
anime.describe()
# Out:
#            anime_id        rating       members
# count  12294.000000  12064.000000  1.229400e+04
# mean   14058.221653      6.473902  1.807134e+04
# std    11455.294701      1.026746  5.482068e+04
# min        1.000000      1.670000  5.000000e+00
# 25%     3484.250000      5.880000  2.250000e+02
# 50%    10260.500000      6.570000  1.550000e+03
# 75%    24794.500000      7.180000  9.437000e+03
# max    34527.000000     10.000000  1.013917e+06

# %%
print(anime.genre.value_counts())
# Out:
# Hentai                                                  823
# Comedy                                                  523
# Music                                                   301
# Kids                                                    199
# Comedy, Slice of Life                                   179
#                                                        ...
# Adventure, Drama, Fantasy, Game, Sci-Fi                   1
# Adventure, Demons, Fantasy, Historical                    1
# Action, Comedy, Drama, Mecha, Music, Sci-Fi, Shounen      1
# Action, Comedy, Fantasy, Mecha, Sci-Fi, Shounen           1
# Hentai, Slice of Life                                     1
# Name: genre, Length: 3264, dtype: int64

# %%
anime.type.tolist()
# Out:
# ['Movie',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'OVA',
#  'Movie',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'OVA',
#  'TV',
#  'TV',
#  'Movie',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'Movie',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'OVA',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'Special',
#  'TV',
#  'TV',
#  'TV',
#  'OVA',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'Movie',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'Movie',
#  'OVA',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'TV',
#  'TV',
#  'TV',
#  'Special',
#  'TV',
#  'TV',
#  'TV',
#  'Movie',
#  'Movie',
#  'TV',
#  'OVA',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
#  'TV',
# ...

# %%
anime_modified.index.tolist()
# Out:
# ['Kimi no Na wa.',
#  'Fullmetal Alchemist: Brotherhood',
#  'Gintama°',
#  'Steins;Gate',
#  'Gintama&#039;',
#  'Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou',
#  'Hunter x Hunter (2011)',
#  'Ginga Eiyuu Densetsu',
#  'Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare',
#  'Gintama&#039;: Enchousen',
#  'Clannad: After Story',
#  'Koe no Katachi',
#  'Gintama',
#  'Code Geass: Hangyaku no Lelouch R2',
#  'Haikyuu!! Second Season',
#  'Sen to Chihiro no Kamikakushi',
#  'Shigatsu wa Kimi no Uso',
#  'Mushishi Zoku Shou 2nd Season',
#  'Ookami Kodomo no Ame to Yuki',
#  'Code Geass: Hangyaku no Lelouch',
#  'Hajime no Ippo',
#  'Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen',
#  'Cowboy Bebop',
#  'One Punch Man',
#  'Mononoke Hime',
#  'Suzumiya Haruhi no Shoushitsu',
#  'Monogatari Series: Second Season',
#  'Mushishi Zoku Shou',
#  'Mushishi',
#  'Tengen Toppa Gurren Lagann',
#  'Great Teacher Onizuka',
#  'Natsume Yuujinchou Go',
# ...

# %%
anime.columns.tolist()
# Out:
# ['anime_id', 'name', 'genre', 'type', 'episodes', 'rating', 'members']

# %%
anime["old"] = True

# %%
print(anime[["name", "episodes"]])
# Out:
#                                                     name episodes
# 0                                         Kimi no Na wa.        1
# 1                       Fullmetal Alchemist: Brotherhood       64
# 2                                               Gintama°       51
# 3                                            Steins;Gate       24
# 4                                          Gintama&#039;       51
# ...                                                  ...      ...
# 12289       Toushindai My Lover: Minami tai Mecha-Minami        1
# 12290                                        Under World        1
# 12291                     Violence Gekiga David no Hoshi        4
# 12292  Violence Gekiga Shin David no Hoshi: Inma Dens...        1
# 12293                   Yasuji no Pornorama: Yacchimae!!        1
#
# [12294 rows x 2 columns]

# %%
anime.drop(["anime_id", "genre", "members"], axis = 1).head(10)
# Out:
#                                                 name   type episodes  rating  \
# 0                                     Kimi no Na wa.  Movie        1    9.37
# 1                   Fullmetal Alchemist: Brotherhood     TV       64    9.26
# 2                                           Gintama°     TV       51    9.25
# 3                                        Steins;Gate     TV       24    9.17
# 4                                      Gintama&#039;     TV       51    9.16
# 5  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...     TV       10    9.15
# 6                             Hunter x Hunter (2011)     TV      148    9.13
# 7                               Ginga Eiyuu Densetsu    OVA      110    9.11
# 8  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...  Movie        1    9.10
# 9                           Gintama&#039;: Enchousen     TV       13    9.11
#
#     old
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True
# 5  True
# 6  True
# 7  True
# 8  True
# 9  True

# %%
anime.drop(range(10), axis = 0).head(10)
# Out:
#     anime_id                                name  \
# 10      4181                Clannad: After Story
# 11     28851                      Koe no Katachi
# 12       918                             Gintama
# 13      2904  Code Geass: Hangyaku no Lelouch R2
# 14     28891             Haikyuu!! Second Season
# 15       199       Sen to Chihiro no Kamikakushi
# 16     23273             Shigatsu wa Kimi no Uso
# 17     24701       Mushishi Zoku Shou 2nd Season
# 18     12355        Ookami Kodomo no Ame to Yuki
# 19      1575     Code Geass: Hangyaku no Lelouch
#
#                                                 genre   type episodes  rating  \
# 10  Drama, Fantasy, Romance, Slice of Life, Supern...     TV       24    9.06
# 11                             Drama, School, Shounen  Movie        1    9.05
# 12  Action, Comedy, Historical, Parody, Samurai, S...     TV      201    9.04
# 13  Action, Drama, Mecha, Military, Sci-Fi, Super ...     TV       25    8.98
# ...

# %%
anime['type'].unique()
# Out:
# array(['Movie', 'TV', 'OVA', 'Special', 'Music', 'ONA', nan], dtype=object)

# %%
anime[anime['type'].isin(['Movie'])]
# Out:
#        anime_id                                               name  \
# 0         32281                                     Kimi no Na wa.
# 8         15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 11        28851                                     Koe no Katachi
# 15          199                      Sen to Chihiro no Kamikakushi
# 18        12355                       Ookami Kodomo no Ame to Yuki
# ...         ...                                                ...
# 11738      3038                            Senya Ichiya Monogatari
# 11805      2755                                          Cleopatra
# 12244     11141                                       Blue Seagull
# 12258     20007                      Hi Gekiga Ukiyoe Senya Ichiya
# 12293     26081                   Yasuji no Pornorama: Yacchimae!!
#
#                                                    genre   type episodes  \
# 0                   Drama, Romance, School, Supernatural  Movie        1
# ...

# %%
anime[anime['type'] == 'Movie'].mean()
# Out:
# /tmp/ipykernel_5553/559584382.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   anime[anime['type'] == 'Movie'].mean()
# anime_id    14898.067291
# rating          6.318058
# members     10360.340716
# dtype: float64

# %%
anime[anime['type'] == 'TV'].mean()
# Out:
# /tmp/ipykernel_5553/2913303942.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   anime[anime['type'] == 'TV'].mean()
# anime_id    11966.169527
# rating          6.902299
# members     42683.658305
# dtype: float64

# %%
anime.drop(['anime_id', 'genre'], axis = 1).sort_values('members', ascending = False).head(20)
# Out:
#                                    name type episodes  rating  members
# 40                           Death Note   TV       37    8.71  1013917
# 86                   Shingeki no Kyojin   TV       25    8.54   896229
# 804                    Sword Art Online   TV       25    7.83   893100
# 1      Fullmetal Alchemist: Brotherhood   TV       64    9.26   793665
# 159                        Angel Beats!   TV       13    8.39   717796
# 19      Code Geass: Hangyaku no Lelouch   TV       25    8.83   715151
# 841                              Naruto   TV      220    7.81   683297
# 3                           Steins;Gate   TV       24    9.17   673572
# 445                    Mirai Nikki (TV)   TV       26    8.07   657190
# 131                           Toradora!   TV       25    8.45   633817
# 582                              Bleach   TV      366    7.95   624055
# 760                          Elfen Lied   TV       13    7.85   623511
# ...

# %%
anime.drop(['anime_id', 'genre'], axis = 1).sort_values('rating', ascending = False)[anime['members'] >= 50000].head(20)
# Out:
# /tmp/ipykernel_5553/128895796.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   anime.drop(['anime_id', 'genre'], axis = 1).sort_values('rating', ascending = False)[anime['members'] >= 50000].head(20)
#                                                  name   type episodes  rating  \
# 0                                      Kimi no Na wa.  Movie        1    9.37
# 1                    Fullmetal Alchemist: Brotherhood     TV       64    9.26
# 2                                            Gintama°     TV       51    9.25
# 3                                         Steins;Gate     TV       24    9.17
# 4                                       Gintama&#039;     TV       51    9.16
# 5   Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...     TV       10    9.15
# 6                              Hunter x Hunter (2011)     TV      148    9.13
# 9                            Gintama&#039;: Enchousen     TV       13    9.11
# ...

# %%
anime[anime['episodes'] == '1818']
# Out:
#       anime_id        name                  genre type episodes  rating  \
# 6296     12393  Oyako Club  Comedy, Slice of Life   TV     1818    6.18
#
#       members
# 6296      160
